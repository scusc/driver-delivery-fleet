# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('E:\\driver_data.csv')
# Out:
#       Distance_Feature  Speeding_Feature
# 0                71.24                28
# 1                52.53                25
# 2                64.54                27
# 3                55.69                22
# 4                54.58                25
# 5                41.91                10
# 6                58.64                20
# 7                52.02                 8
# 8                31.25                34
# 9                44.31                19
# 10               49.35                40
# 11               58.07                45
# 12               44.22                22
# 13               55.73                19
# 14               46.63                43
# 15               52.97                32
# 16               46.25                35
# 17               51.55                27
# 18               57.05                26
# 19               58.45                30
# 20               43.42                23
# 21               55.68                37
# ...

# %%
df=pd.read_csv('E:\\driver_data.csv')

# %%
df.dropna()
# Out:
#       Distance_Feature  Speeding_Feature
# 0                71.24                28
# 1                52.53                25
# 2                64.54                27
# 3                55.69                22
# 4                54.58                25
# 5                41.91                10
# 6                58.64                20
# 7                52.02                 8
# 8                31.25                34
# 9                44.31                19
# 10               49.35                40
# 11               58.07                45
# 12               44.22                22
# 13               55.73                19
# 14               46.63                43
# 15               52.97                32
# 16               46.25                35
# 17               51.55                27
# 18               57.05                26
# 19               58.45                30
# 20               43.42                23
# 21               55.68                37
# ...

# %%
import matplotlib.pyplot as plt
from sklearn import cluster
from sklearn.cluster import KMeans

# %%
k = cluster.KMeans(n_clusters=4).fit(df)
centroids = k.cluster_centers_
print(centroids)
plt.scatter(df['Distance_Feature'],df['Speeding_Feature'],c= k.labels_.astype(float),alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='blue')
plt.title("driver delivery fleet")
plt.xlabel("distance feature")
plt.ylabel("speeding feature")
plt.show()
# Out:
# [[ 49.99263253   5.20447169]
#  [180.34311782  10.52011494]
#  [ 50.40482436  32.36533958]
#  [177.83509615  70.28846154]]

# %%
from yellowbrick.cluster import SilhouetteVisualizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
range_n_clusters = list (range(2,10))
for n_clusters in range_n_clusters:
    clusterer = KMeans (n_clusters=n_clusters).fit(df)
    preds = clusterer.predict(df)
    centers = clusterer.cluster_centers_
    score = silhouette_score (df, preds, metric='euclidean')
    model = SilhouetteVisualizer(KMeans(n_clusters))
    model.fit(df)
    model.show()
    print ("For n_clusters = {}, silhouette score is {}".format(n_clusters, score))
# Out:
# For n_clusters = 2, silhouette score is 0.8490223286225532
# For n_clusters = 3, silhouette score is 0.8231396834167266
# For n_clusters = 4, silhouette score is 0.5911323766293183
# For n_clusters = 5, silhouette score is 0.5128161654454148
# For n_clusters = 6, silhouette score is 0.48561104817990663
# For n_clusters = 7, silhouette score is 0.45906039687260586
# For n_clusters = 8, silhouette score is 0.4505307305813811
# For n_clusters = 9, silhouette score is 0.4458428581709819

# %%
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
dendrogram = sch.dendrogram(sch.linkage(df, method  = "ward"))
plt.title('Dendrogram')
plt.xlabel('samples')
plt.ylabel('driver delivery fleets')
plt.show()

# %%
for n_clusters in range_n_clusters:
    ac = AgglomerativeClustering(n_clusters) 
    plt.figure(figsize =(6, 6)) 
    plt.scatter(df['Distance_Feature'], df['Speeding_Feature'],  
    c = ac.fit_predict(df), cmap ='rainbow')
    score = silhouette_score(df, ac.fit_predict(df), metric='euclidean')
    plt.show() 
    print ("For n_clusters = {}, silhouette score is {}".format(n_clusters, score))
# Out:
# For n_clusters = 2, silhouette score is 0.8490223286225532
# For n_clusters = 3, silhouette score is 0.8216555622432279
# For n_clusters = 4, silhouette score is 0.5814946234165147
# For n_clusters = 5, silhouette score is 0.49013371028194974
# For n_clusters = 6, silhouette score is 0.4613938519498829
# For n_clusters = 7, silhouette score is 0.43726884768177937
# For n_clusters = 8, silhouette score is 0.42812979869514595
# For n_clusters = 9, silhouette score is 0.4252112225810456
